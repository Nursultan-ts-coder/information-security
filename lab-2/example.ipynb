# %% [markdown]
# 1. Create file with command:
# ```bash
#  sudo nano /usr/local/bin/system_info
#  ```
#
#  And paste the following code:
#
# ```bash
# #!/bin/bash
# echo "Hostname: $(hostname)"
# echo "Current User: $(whoami)"
# echo "Disk Space: $(df -h)"
# ```

# %% [markdown]
# 2. Make it executable:

# %%
sudo chmod +x /usr/local/bin/system_info

# %% [markdown]
# 3. Test it:

# %%
 system_info

# %% [raw]
# Hostname: Nursultans-MacBook-Air.local
# Current User: nursultanlukmanov
# Disk Space: Filesystem        Size    Used   Avail Capacity iused ifree %iused  Mounted on
# /dev/disk3s1s1   228Gi    11Gi    28Gi    30%    453k  291M    0%   /
# devfs            201Ki   201Ki     0Bi   100%     694     0  100%   /dev
# /dev/disk3s6     228Gi   2.0Gi    28Gi     7%       2  291M    0%   /System/Volumes/VM
# /dev/disk3s2     228Gi   9.0Gi    28Gi    25%    1.8k  291M    0%   /System/Volumes/Preboot
# /dev/disk3s4     228Gi   5.3Mi    28Gi     1%      68  291M    0%   /System/Volumes/Update
# /dev/disk1s2     500Mi   6.0Mi   482Mi     2%       1  4.9M    0%   /System/Volumes/xarts
# /dev/disk1s1     500Mi   5.8Mi   482Mi     2%      34  4.9M    0%   /System/Volumes/iSCPreboot
# /dev/disk1s3     500Mi   1.1Mi   482Mi     1%      82  4.9M    0%   /System/Volumes/Hardware
# /dev/disk3s5     228Gi   176Gi    28Gi    87%    2.1M  291M    1%   /System/Volumes/Data
# map auto_home      0Bi     0Bi     0Bi   100%       0     0     -   /System/Volumes/Data/home
# /dev/disk2s1     5.0Gi   1.9Gi   3.1Gi    38%      66   33M    0%   /System/Volumes/Update/SFR/mnt1
