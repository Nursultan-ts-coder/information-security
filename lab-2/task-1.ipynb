# %% [markdown]
# ### Task 1
#
# Create a script to display
# Write a shell script named greet.sh that:
# Outputs a greeting message, e.g., "Hello, [username]!"

# %% [markdown]
# - open nano editor

# %%
nano /usr/local/bin/greet
# Out:
# /usr/local/bin/greet

# %% [markdown]
# - enter the script:

# %%
echo "Hello, $(whoami)!"
# Out:
# echo "Hello, $(whoami)"""
# Note: all executions are function-scoped as we do not assume the code below executes in an isolated kernel environment.
# """
# bash: Note:: command not found
# bash: command substitution: line 0: unexpected EOF while looking for matching `"'
# bash: command substitution: line 2: syntax error: unexpected end of file
# Hello,
# bash: Note:: command not found

# %% [markdown]
# - Make it executable by giving the permissions

# %%
sudo chmod +x /usr/local/bin/greet
