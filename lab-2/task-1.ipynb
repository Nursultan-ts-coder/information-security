# %% [markdown]
# ### Task 1
#
# Create a script to display
# Write a shell script named greet.sh that:
# Outputs a greeting message, e.g., "Hello, [username]!"

# %% [markdown]
# - open nano editor

# %%
sudo nano /usr/local/bin/greet

# %% [raw]
# (jupyter-env) nursultanlukmanov@Nursultans-MacBook-Air labs % greet
# Hello, nursultanlukmanov!

# %% [markdown]
# - enter the script:

# %%
echo "Hello, $(whoami)!"

# %% [raw]
# Hello, nursultanlukmanov

# %% [markdown]
# - Make it executable by giving the permissions

# %%
sudo chmod +x /usr/local/bin/greet
