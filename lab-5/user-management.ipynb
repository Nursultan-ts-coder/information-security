# %% [markdown]
# 1. Open the terminal and run the following commands:

# %%
sudo adduser hacker

# %% [markdown]
# **Output:** (Interactive prompt for password and user details)

# %% [markdown]
# The system will prompt you to create and confirm a password and other information for the new user.

# %% [markdown]
# 2. Verify the user creation by running:

# %%
cat /etc/passwd

# %% [markdown]
# **Output:** (Contains user entries, example)
#
# ```
# root:x:0:0:root:/root:/bin/bash
# ...
# hacker:x:1001:1001::/home/hacker:/bin/bash
# ```

# %% [markdown]
# 3. Login as your new user

# %%
su - hacker

# %% [markdown]
# **Output:** (No visible output - switches to hacker user)

# %% [markdown]
# 4. Verify login by running the following command:

# %%
whoami

# %% [markdown]
# **Output:**
#
# ```
# hacker
# ```

# %% [raw]
# hacker

# %% [markdown]
# 5. To delete this user you should first kill current login session

# %%
pkill -KILL -u hacker

# %% [markdown]
# **Output:** (No visible output on success)

# %% [markdown]
# 6. Delete the user by command:

# %%
deluser --remove-home --force user1

# %% [markdown]
# **Output:** (No visible output on success - note: user1 may not exist in this example)

# %% [markdown]
# 7. Verify deletion:

# %%
cat /etc/passwd

# %% [markdown]
# **Output:** (User should no longer be in the list)

# %% [markdown]
# Now there should not be user1

# %% [markdown]
# ### Task:
#
# Try to discover user groups, create new user and add him to new created group

# %% [markdown]
# - Add user

# %%
sudo adduser hacker

# %% [markdown]
# **Output:** (Interactive prompt for password and user details)

# %% [markdown]
# - Add new user group

# %%
sudo groupadd hackers

# %% [markdown]
# **Output:** (No visible output on success)

# %% [markdown]
# - Add new user to new group

# %%
sudo usermod -aG hackers hacker

# %% [markdown]
# **Output:** (No visible output on success - hacker user added to hackers group)
