# %% [markdown]
# Task: try to discover how to change file owner and group and how it affects to file usage

# %%
touch file-1.txt

# %%
sudo chown hacker:hackers file-1.txt

# %% [markdown]
# How to see the result, how affected the command to the file-1.txt

# %%
ls -l file-1.txt
